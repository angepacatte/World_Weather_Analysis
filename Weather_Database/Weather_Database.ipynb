# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e38fef588d0e47c2f9fbf339bf97916c

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faanui
# Processing Record 2 of Set 1 | buraydah
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | ventspils
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | hualmay
# Processing Record 18 of Set 1 | shieli
# Processing Record 19 of Set 1 | boyuibe
# Processing Record 20 of Set 1 | tarancon
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | baie-comeau
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | sosnovoborsk
# Processing Record 26 of Set 1 | andenes
# Processing Record 27 of Set 1 | sao felix do xingu
# Processing Record 28 of Set 1 | nouadhibou
# Processing Record 29 of Set 1 | along
# Processing Record 30 of Set 1 | vuktyl
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | dunedin
# Processing Record 33 of Set 1 | alyangula
# Processing Record 34 of Set 1 | roald
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | vestmannaeyjar
# Processing Record 38 of Set 1 | laguna
# Processing Record 39 of Set 1 | amapa
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | tarakan
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | tateyama
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | altay
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | port hedland
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | ostrovnoy
# Processing Record 6 of Set 2 | bandarbeyla
# Processing Record 7 of Set 2 | bayir
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | svetlogorsk
# Processing Record 12 of Set 2 | qaqortoq
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | lata
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | pitimbu
# Processing Record 18 of Set 2 | polunochnoye
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | rehoboth
# Processing Record 22 of Set 2 | pooler
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | yar-sale
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | kralovice
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | tezu
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | san andres
# Processing Record 32 of Set 2 | nadym
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | srednekolymsk
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | cockburn town
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | vostok
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | boueni
# Processing Record 41 of Set 2 | buala
# Processing Record 42 of Set 2 | selma
# Processing Record 43 of Set 2 | yaan
# Processing Record 44 of Set 2 | kristiansund
# Processing Record 45 of Set 2 | vila franca do campo
# Processing Record 46 of Set 2 | maceio
# Processing Record 47 of Set 2 | mosjoen
# Processing Record 48 of Set 2 | kachikau
# City not found. Skipping...
# Processing Record 49 of Set 2 | qiongshan
# Processing Record 50 of Set 2 | wattegama
# Processing Record 1 of Set 3 | kesova gora
# Processing Record 2 of Set 3 | northam
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | ambilobe
# Processing Record 5 of Set 3 | pisco
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | mareeba
# Processing Record 9 of Set 3 | ahar
# Processing Record 10 of Set 3 | novovasylivka
# Processing Record 11 of Set 3 | rabat
# Processing Record 12 of Set 3 | havoysund
# Processing Record 13 of Set 3 | oussouye
# Processing Record 14 of Set 3 | yulara
# Processing Record 15 of Set 3 | mao
# Processing Record 16 of Set 3 | comodoro rivadavia
# Processing Record 17 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 3 | goderich
# Processing Record 19 of Set 3 | muriwai beach
# Processing Record 20 of Set 3 | wanning
# Processing Record 21 of Set 3 | inhambane
# Processing Record 22 of Set 3 | shiyan
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | tema
# Processing Record 25 of Set 3 | atar
# Processing Record 26 of Set 3 | megion
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 3 | touros
# Processing Record 30 of Set 3 | axim
# Processing Record 31 of Set 3 | lugoba
# Processing Record 32 of Set 3 | guerrero negro
# Processing Record 33 of Set 3 | mildura
# Processing Record 34 of Set 3 | blackwater
# Processing Record 35 of Set 3 | abu samrah
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | yoichi
# Processing Record 38 of Set 3 | guacimo
# Processing Record 39 of Set 3 | haines junction
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | ayan
# Processing Record 42 of Set 3 | mana
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | mehamn
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | berlevag
# Processing Record 50 of Set 3 | kyren
# Processing Record 1 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 2 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 4 | mataura
# Processing Record 5 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 6 of Set 4 | ucluelet
# Processing Record 7 of Set 4 | vallenar
# Processing Record 8 of Set 4 | swan hill
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | truth or consequences
# Processing Record 11 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 4 | los algarrobos
# Processing Record 13 of Set 4 | poum
# Processing Record 14 of Set 4 | nizhniy baskunchak
# Processing Record 15 of Set 4 | ribeira grande
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | laukaa
# Processing Record 18 of Set 4 | vieux-habitants
# Processing Record 19 of Set 4 | vao
# Processing Record 20 of Set 4 | mitsamiouli
# Processing Record 21 of Set 4 | karratha
# Processing Record 22 of Set 4 | meulaboh
# Processing Record 23 of Set 4 | waynesboro
# Processing Record 24 of Set 4 | barsovo
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | rio claro
# Processing Record 28 of Set 4 | mahina
# Processing Record 29 of Set 4 | bluff
# Processing Record 30 of Set 4 | la rioja
# Processing Record 31 of Set 4 | larap
# Processing Record 32 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 4 | puerto ayora
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | plettenberg bay
# Processing Record 36 of Set 4 | alexandria
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | namibe
# Processing Record 41 of Set 4 | rio gallegos
# Processing Record 42 of Set 4 | sassandra
# Processing Record 43 of Set 4 | katherine
# Processing Record 44 of Set 4 | ambatofinandrahana
# Processing Record 45 of Set 4 | isiolo
# Processing Record 46 of Set 4 | charqueadas
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | samarai
# Processing Record 49 of Set 4 | havre-saint-pierre
# Processing Record 50 of Set 4 | ampanihy
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | palmer
# Processing Record 4 of Set 5 | smithers
# Processing Record 5 of Set 5 | tupik
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | oranjemund
# Processing Record 8 of Set 5 | kahului
# Processing Record 9 of Set 5 | maningrida
# Processing Record 10 of Set 5 | oksfjord
# Processing Record 11 of Set 5 | requena
# Processing Record 12 of Set 5 | burnie
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | salta
# Processing Record 15 of Set 5 | alicia
# Processing Record 16 of Set 5 | la ronge
# Processing Record 17 of Set 5 | avera
# Processing Record 18 of Set 5 | halifax
# Processing Record 19 of Set 5 | neuquen
# Processing Record 20 of Set 5 | hambantota
# Processing Record 21 of Set 5 | velingara
# Processing Record 22 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 23 of Set 5 | kloulklubed
# Processing Record 24 of Set 5 | huanuco
# Processing Record 25 of Set 5 | coahuayana
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | bilma
# Processing Record 29 of Set 5 | ilulissat
# Processing Record 30 of Set 5 | newry
# Processing Record 31 of Set 5 | birjand
# Processing Record 32 of Set 5 | takob
# City not found. Skipping...
# Processing Record 33 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 5 | ouadda
# Processing Record 35 of Set 5 | aksu
# Processing Record 36 of Set 5 | korla
# Processing Record 37 of Set 5 | clyde river
# Processing Record 38 of Set 5 | bonanza
# Processing Record 39 of Set 5 | tortoli
# Processing Record 40 of Set 5 | flagstaff
# Processing Record 41 of Set 5 | nisia floresta
# Processing Record 42 of Set 5 | garowe
# Processing Record 43 of Set 5 | ibatiba
# Processing Record 44 of Set 5 | ahipara
# Processing Record 45 of Set 5 | sangar
# Processing Record 46 of Set 5 | kapit
# Processing Record 47 of Set 5 | cordoba
# Processing Record 48 of Set 5 | itupiranga
# Processing Record 49 of Set 5 | ixtapa
# Processing Record 50 of Set 5 | tamano
# Processing Record 1 of Set 6 | nantucket
# Processing Record 2 of Set 6 | kobojango
# City not found. Skipping...
# Processing Record 3 of Set 6 | flinders
# Processing Record 4 of Set 6 | saint-francois
# Processing Record 5 of Set 6 | behbahan
# Processing Record 6 of Set 6 | codrington
# Processing Record 7 of Set 6 | langres
# Processing Record 8 of Set 6 | shimanovsk
# Processing Record 9 of Set 6 | dudinka
# Processing Record 10 of Set 6 | mae sai
# Processing Record 11 of Set 6 | wenling
# Processing Record 12 of Set 6 | florence
# Processing Record 13 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 6 | talcahuano
# Processing Record 15 of Set 6 | moree
# Processing Record 16 of Set 6 | tabou
# Processing Record 17 of Set 6 | upernavik
# Processing Record 18 of Set 6 | torbay
# Processing Record 19 of Set 6 | nabire
# Processing Record 20 of Set 6 | turukhansk
# Processing Record 21 of Set 6 | biloela
# Processing Record 22 of Set 6 | coolum beach
# Processing Record 23 of Set 6 | hitchin
# Processing Record 24 of Set 6 | lichinga
# Processing Record 25 of Set 6 | te anau
# Processing Record 26 of Set 6 | bakchar
# Processing Record 27 of Set 6 | lorengau
# Processing Record 28 of Set 6 | mukhen
# Processing Record 29 of Set 6 | huayapam
# City not found. Skipping...
# Processing Record 30 of Set 6 | tavricheskoye
# Processing Record 31 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 6 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 6 | pakala
# Processing Record 34 of Set 6 | petukhovo
# Processing Record 35 of Set 6 | yeniseysk
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | madras
# Processing Record 39 of Set 6 | rio tercero
# Processing Record 40 of Set 6 | ancud
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | le port
# Processing Record 43 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | hanna
# Processing Record 45 of Set 6 | bereda
# Processing Record 46 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 6 | bolshaya rechka
# Processing Record 48 of Set 6 | viedma
# Processing Record 49 of Set 6 | fairview
# Processing Record 50 of Set 6 | zhangye
# Processing Record 1 of Set 7 | deer lake
# Processing Record 2 of Set 7 | kathu
# Processing Record 3 of Set 7 | hue
# Processing Record 4 of Set 7 | bubaque
# Processing Record 5 of Set 7 | nelidovo
# Processing Record 6 of Set 7 | mahebourg
# Processing Record 7 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 7 | yuzhnyy
# Processing Record 9 of Set 7 | kisangani
# Processing Record 10 of Set 7 | yarada
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | novikovo
# Processing Record 13 of Set 7 | neryungri
# Processing Record 14 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 15 of Set 7 | huarmey
# Processing Record 16 of Set 7 | basi
# Processing Record 17 of Set 7 | lavrentiya
# Processing Record 18 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 7 | puchezh
# Processing Record 20 of Set 7 | chino valley
# Processing Record 21 of Set 7 | kalmunai
# Processing Record 22 of Set 7 | maralal
# Processing Record 23 of Set 7 | iquitos
# Processing Record 24 of Set 7 | severo-kurilsk
# Processing Record 25 of Set 7 | guiratinga
# Processing Record 26 of Set 7 | muros
# Processing Record 27 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 28 of Set 7 | kilingi-nomme
# Processing Record 29 of Set 7 | pevek
# Processing Record 30 of Set 7 | hervey bay
# Processing Record 31 of Set 7 | pangnirtung
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | aasiaat
# Processing Record 34 of Set 7 | dicabisagan
# Processing Record 35 of Set 7 | bardiyah
# Processing Record 36 of Set 7 | valley city
# Processing Record 37 of Set 7 | baracoa
# Processing Record 38 of Set 7 | alpena
# Processing Record 39 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 7 | tiznit
# Processing Record 41 of Set 7 | port hueneme
# Processing Record 42 of Set 7 | barranco
# Processing Record 43 of Set 7 | cidreira
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | strezhevoy
# Processing Record 46 of Set 7 | aklavik
# Processing Record 47 of Set 7 | carnarvon
# Processing Record 48 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | ballina
# Processing Record 1 of Set 8 | ciudad bolivar
# Processing Record 2 of Set 8 | tilichiki
# Processing Record 3 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 8 | tadine
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | peniche
# Processing Record 7 of Set 8 | kichmengskiy gorodok
# Processing Record 8 of Set 8 | mykhaylivka
# Processing Record 9 of Set 8 | tomatlan
# Processing Record 10 of Set 8 | iqaluit
# Processing Record 11 of Set 8 | lempaala
# Processing Record 12 of Set 8 | samarkand
# Processing Record 13 of Set 8 | brokopondo
# Processing Record 14 of Set 8 | san policarpo
# Processing Record 15 of Set 8 | calawag
# Processing Record 16 of Set 8 | caravelas
# Processing Record 17 of Set 8 | naze
# Processing Record 18 of Set 8 | peace river
# Processing Record 19 of Set 8 | lagoa
# Processing Record 20 of Set 8 | isoka
# Processing Record 21 of Set 8 | stornoway
# Processing Record 22 of Set 8 | paamiut
# Processing Record 23 of Set 8 | angoche
# Processing Record 24 of Set 8 | ritchie
# Processing Record 25 of Set 8 | houma
# Processing Record 26 of Set 8 | sept-iles
# Processing Record 27 of Set 8 | la paz
# Processing Record 28 of Set 8 | nuuk
# Processing Record 29 of Set 8 | mizdah
# Processing Record 30 of Set 8 | port hardy
# Processing Record 31 of Set 8 | dembi dolo
# Processing Record 32 of Set 8 | phangnga
# Processing Record 33 of Set 8 | hay river
# Processing Record 34 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 8 | amvrosiyivka
# Processing Record 36 of Set 8 | sioux lookout
# Processing Record 37 of Set 8 | padang
# Processing Record 38 of Set 8 | pathum thani
# Processing Record 39 of Set 8 | kamenka
# Processing Record 40 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 8 | tuatapere
# Processing Record 42 of Set 8 | takoradi
# Processing Record 43 of Set 8 | chapais
# Processing Record 44 of Set 8 | beringovskiy
# Processing Record 45 of Set 8 | pimentel
# Processing Record 46 of Set 8 | bhubaneswar
# Processing Record 47 of Set 8 | cape coast
# Processing Record 48 of Set 8 | baghdad
# Processing Record 49 of Set 8 | sokone
# Processing Record 50 of Set 8 | saucillo
# Processing Record 1 of Set 9 | tessalit
# Processing Record 2 of Set 9 | thomaston
# Processing Record 3 of Set 9 | abonnema
# Processing Record 4 of Set 9 | wahiawa
# Processing Record 5 of Set 9 | marawi
# Processing Record 6 of Set 9 | deputatskiy
# Processing Record 7 of Set 9 | tres lagoas
# Processing Record 8 of Set 9 | saint-augustin
# Processing Record 9 of Set 9 | sualkuchi
# Processing Record 10 of Set 9 | geraldton
# Processing Record 11 of Set 9 | waipawa
# Processing Record 12 of Set 9 | olafsvik
# Processing Record 13 of Set 9 | klyuchi
# Processing Record 14 of Set 9 | sola
# Processing Record 15 of Set 9 | zhigansk
# Processing Record 16 of Set 9 | tromso
# Processing Record 17 of Set 9 | rawson
# Processing Record 18 of Set 9 | belaya gora
# Processing Record 19 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 20 of Set 9 | los llanos de aridane
# Processing Record 21 of Set 9 | taikang
# Processing Record 22 of Set 9 | anadyr
# Processing Record 23 of Set 9 | obo
# Processing Record 24 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 25 of Set 9 | berdigestyakh
# Processing Record 26 of Set 9 | uglovskoye
# Processing Record 27 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 9 | thabazimbi
# Processing Record 29 of Set 9 | morondava
# Processing Record 30 of Set 9 | batagay
# Processing Record 31 of Set 9 | anito
# Processing Record 32 of Set 9 | pangai
# Processing Record 33 of Set 9 | caucaia
# Processing Record 34 of Set 9 | santo antonio do sudoeste
# Processing Record 35 of Set 9 | orlik
# Processing Record 36 of Set 9 | kruisfontein
# Processing Record 37 of Set 9 | asau
# Processing Record 38 of Set 9 | nenjiang
# Processing Record 39 of Set 9 | salalah
# Processing Record 40 of Set 9 | vila velha
# Processing Record 41 of Set 9 | corning
# Processing Record 42 of Set 9 | raton
# Processing Record 43 of Set 9 | dodge city
# Processing Record 44 of Set 9 | krasnoselkup
# Processing Record 45 of Set 9 | mindelo
# Processing Record 46 of Set 9 | santa vitoria do palmar
# Processing Record 47 of Set 9 | half moon bay
# Processing Record 48 of Set 9 | panacan
# Processing Record 49 of Set 9 | kampong thum
# Processing Record 50 of Set 9 | pedernales
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | gizo
# Processing Record 3 of Set 10 | inirida
# Processing Record 4 of Set 10 | gimli
# Processing Record 5 of Set 10 | cap malheureux
# Processing Record 6 of Set 10 | galle
# Processing Record 7 of Set 10 | kachug
# Processing Record 8 of Set 10 | tulagi
# Processing Record 9 of Set 10 | zanesville
# Processing Record 10 of Set 10 | acarau
# Processing Record 11 of Set 10 | sturgeon bay
# Processing Record 12 of Set 10 | gravelbourg
# Processing Record 13 of Set 10 | charlestown
# Processing Record 14 of Set 10 | hamilton
# Processing Record 15 of Set 10 | gigmoto
# Processing Record 16 of Set 10 | sfantu gheorghe
# Processing Record 17 of Set 10 | erenhot
# Processing Record 18 of Set 10 | burica
# City not found. Skipping...
# Processing Record 19 of Set 10 | volksrust
# Processing Record 20 of Set 10 | marzuq
# Processing Record 21 of Set 10 | constitucion
# Processing Record 22 of Set 10 | harper
# Processing Record 23 of Set 10 | dresden
# Processing Record 24 of Set 10 | utete
# Processing Record 25 of Set 10 | visnes
# Processing Record 26 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 10 | leeuwarden
# Processing Record 28 of Set 10 | cavalcante
# Processing Record 29 of Set 10 | steamboat springs
# Processing Record 30 of Set 10 | norman wells
# Processing Record 31 of Set 10 | makokou
# Processing Record 32 of Set 10 | kakching
# Processing Record 33 of Set 10 | calbuco
# Processing Record 34 of Set 10 | itapetinga
# Processing Record 35 of Set 10 | jishou
# Processing Record 36 of Set 10 | mantua
# Processing Record 37 of Set 10 | ulladulla
# Processing Record 38 of Set 10 | adrar
# Processing Record 39 of Set 10 | sun valley
# Processing Record 40 of Set 10 | beasain
# Processing Record 41 of Set 10 | tabas
# Processing Record 42 of Set 10 | evansville
# Processing Record 43 of Set 10 | slave lake
# Processing Record 44 of Set 10 | acapulco
# Processing Record 45 of Set 10 | smolenka
# Processing Record 46 of Set 10 | messina
# Processing Record 47 of Set 10 | tempio pausania
# Processing Record 48 of Set 10 | sibolga
# Processing Record 49 of Set 10 | marsa matruh
# Processing Record 50 of Set 10 | bonavista
# Processing Record 1 of Set 11 | staraya toropa
# Processing Record 2 of Set 11 | banda aceh
# Processing Record 3 of Set 11 | springdale
# Processing Record 4 of Set 11 | havelock
# Processing Record 5 of Set 11 | masyaf
# Processing Record 6 of Set 11 | komsomolskiy
# Processing Record 7 of Set 11 | yefremov
# Processing Record 8 of Set 11 | vardo
# Processing Record 9 of Set 11 | jieshi
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | umm kaddadah
# Processing Record 12 of Set 11 | eufaula
# Processing Record 13 of Set 11 | ca mau
# Processing Record 14 of Set 11 | vanavara
# Processing Record 15 of Set 11 | velasco ibarra
# Processing Record 16 of Set 11 | gardenstown
# Processing Record 17 of Set 11 | kargasok
# Processing Record 18 of Set 11 | smolensk
# Processing Record 19 of Set 11 | ingham
# Processing Record 20 of Set 11 | kadur
# Processing Record 21 of Set 11 | poronaysk
# Processing Record 22 of Set 11 | motygino
# Processing Record 23 of Set 11 | ahualulco
# Processing Record 24 of Set 11 | warmbad
# Processing Record 25 of Set 11 | luebo
# Processing Record 26 of Set 11 | emba
# Processing Record 27 of Set 11 | zile
# Processing Record 28 of Set 11 | hami
# Processing Record 29 of Set 11 | ashland
# Processing Record 30 of Set 11 | moose factory
# Processing Record 31 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 32 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 33 of Set 11 | williams lake
# Processing Record 34 of Set 11 | saintes
# Processing Record 35 of Set 11 | yicheng
# Processing Record 36 of Set 11 | ankang
# Processing Record 37 of Set 11 | semirom
# Processing Record 38 of Set 11 | meoqui
# Processing Record 39 of Set 11 | bilibino
# Processing Record 40 of Set 11 | krasnogorskoye
# Processing Record 41 of Set 11 | dhanwar
# Processing Record 42 of Set 11 | lewisporte
# Processing Record 43 of Set 11 | bagdarin
# Processing Record 44 of Set 11 | saldanha
# Processing Record 45 of Set 11 | ulaangom
# Processing Record 46 of Set 11 | kilifarevo
# Processing Record 47 of Set 11 | faya
# Processing Record 48 of Set 11 | cayenne
# Processing Record 49 of Set 11 | pasni
# Processing Record 50 of Set 11 | wabana
# Processing Record 1 of Set 12 | nishihara
# Processing Record 2 of Set 12 | westport
# Processing Record 3 of Set 12 | aiquile
# Processing Record 4 of Set 12 | sumter
# Processing Record 5 of Set 12 | talnakh
# Processing Record 6 of Set 12 | parsons
# Processing Record 7 of Set 12 | bom jesus
# Processing Record 8 of Set 12 | aden
# Processing Record 9 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 10 of Set 12 | opuwo
# Processing Record 11 of Set 12 | varhaug
# Processing Record 12 of Set 12 | lakselv
# Processing Record 13 of Set 12 | serenje
# Processing Record 14 of Set 12 | belle glade
# Processing Record 15 of Set 12 | huangyan
# Processing Record 16 of Set 12 | dickinson
# Processing Record 17 of Set 12 | fukue
# Processing Record 18 of Set 12 | isangel
# Processing Record 19 of Set 12 | tynda
# Processing Record 20 of Set 12 | dimbokro
# Processing Record 21 of Set 12 | maniitsoq
# Processing Record 22 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 23 of Set 12 | itacoatiara
# Processing Record 24 of Set 12 | itarema
# Processing Record 25 of Set 12 | cuiluan
# Processing Record 26 of Set 12 | iwaki
# Processing Record 27 of Set 12 | sembe
# Processing Record 28 of Set 12 | benjamin aceval
# Processing Record 29 of Set 12 | brooks
# Processing Record 30 of Set 12 | laem sing
# Processing Record 31 of Set 12 | dwarka
# Processing Record 32 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 12 | amos
# Processing Record 34 of Set 12 | dyersburg
# Processing Record 35 of Set 12 | thatta
# Processing Record 36 of Set 12 | hasaki
# Processing Record 37 of Set 12 | honningsvag
# Processing Record 38 of Set 12 | grand gaube
# Processing Record 39 of Set 12 | imbituba
# Processing Record 40 of Set 12 | ati
# Processing Record 41 of Set 12 | aljezur
# Processing Record 42 of Set 12 | worcester
# Processing Record 43 of Set 12 | ape
# Processing Record 44 of Set 12 | tongliao
# Processing Record 45 of Set 12 | kieta
# Processing Record 46 of Set 12 | nemuro
# Processing Record 47 of Set 12 | acari
# Processing Record 48 of Set 12 | ginir
# Processing Record 49 of Set 12 | xanxere
# Processing Record 50 of Set 12 | rabo de peixe
# Processing Record 1 of Set 13 | mwinilunga
# Processing Record 2 of Set 13 | yian
# City not found. Skipping...
# Processing Record 3 of Set 13 | woodward
# Processing Record 4 of Set 13 | torres
# Processing Record 5 of Set 13 | pilikwe
# Processing Record 6 of Set 13 | indiaroba
# Processing Record 7 of Set 13 | monkey bay
# Processing Record 8 of Set 13 | eureka
# Processing Record 9 of Set 13 | shelburne
# Processing Record 10 of Set 13 | wilkie
# Processing Record 11 of Set 13 | medea
# Processing Record 12 of Set 13 | pietarsaari
# Processing Record 13 of Set 13 | skibbereen
# Processing Record 14 of Set 13 | jiuquan
# Processing Record 15 of Set 13 | tual
# Processing Record 16 of Set 13 | balkhash
# Processing Record 17 of Set 13 | pemberton
# Processing Record 18 of Set 13 | harwich
# Processing Record 19 of Set 13 | dordrecht
# Processing Record 20 of Set 13 | arroyo
# Processing Record 21 of Set 13 | mahibadhoo
# Processing Record 22 of Set 13 | rudbar
# Processing Record 23 of Set 13 | parvatipuram
# Processing Record 24 of Set 13 | aksarka
# Processing Record 25 of Set 13 | boende
# Processing Record 26 of Set 13 | bure
# Processing Record 27 of Set 13 | lunglei
# Processing Record 28 of Set 13 | genhe
# Processing Record 29 of Set 13 | aguimes
# Processing Record 30 of Set 13 | las vegas
# Processing Record 31 of Set 13 | formosa
# Processing Record 32 of Set 13 | coihaique
# Processing Record 33 of Set 13 | leshan
# Processing Record 34 of Set 13 | salmas
# Processing Record 35 of Set 13 | mormugao
# Processing Record 36 of Set 13 | kamen-na-obi
# Processing Record 37 of Set 13 | khani
# Processing Record 38 of Set 13 | cururupu
# Processing Record 39 of Set 13 | solnechnyy
# Processing Record 40 of Set 13 | fremont
# Processing Record 41 of Set 13 | moyobamba
# Processing Record 42 of Set 13 | tenenkou
# Processing Record 43 of Set 13 | booue
# Processing Record 44 of Set 13 | lasa
# Processing Record 45 of Set 13 | ust-nera
# Processing Record 46 of Set 13 | korocha
# Processing Record 47 of Set 13 | kesennuma
# City not found. Skipping...
# Processing Record 48 of Set 13 | glace bay
# Processing Record 49 of Set 13 | maykopskoye
# Processing Record 50 of Set 13 | chandbali
# Processing Record 1 of Set 14 | richards bay
# Processing Record 2 of Set 14 | dinguiraye
# Processing Record 3 of Set 14 | talara
# Processing Record 4 of Set 14 | opotiki
# Processing Record 5 of Set 14 | amarante
# Processing Record 6 of Set 14 | brasilia
# Processing Record 7 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 14 | huittinen
# Processing Record 10 of Set 14 | margate
# Processing Record 11 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 12 of Set 14 | champerico
# Processing Record 13 of Set 14 | kharan
# Processing Record 14 of Set 14 | vila
# Processing Record 15 of Set 14 | vaitape
# Processing Record 16 of Set 14 | ust-kuyga
# Processing Record 17 of Set 14 | ribnitz-damgarten
# Processing Record 18 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 14 | safaga
# Processing Record 20 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 14 | newton
# Processing Record 22 of Set 14 | yeppoon
# Processing Record 23 of Set 14 | namatanai
# Processing Record 24 of Set 14 | juneau
# Processing Record 25 of Set 14 | san quintin
# Processing Record 26 of Set 14 | port-gentil
# Processing Record 27 of Set 14 | jaroslaw
# Processing Record 28 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 14 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 30 of Set 14 | alta floresta
# Processing Record 31 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 14 | inuvik
# Processing Record 33 of Set 14 | dawlatabad
# Processing Record 34 of Set 14 | dingle
# Processing Record 35 of Set 14 | valentin gomez farias
# Processing Record 36 of Set 14 | alma
# Processing Record 37 of Set 14 | onalaska
# Processing Record 38 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 14 | kamphaeng phet
# Processing Record 40 of Set 14 | camacupa
# Processing Record 41 of Set 14 | high level
# Processing Record 42 of Set 14 | katobu
# Processing Record 43 of Set 14 | shenjiamen
# Processing Record 44 of Set 14 | sechura
# Processing Record 45 of Set 14 | rundu
# Processing Record 46 of Set 14 | tevaitoa
# Processing Record 47 of Set 14 | innisfail
# Processing Record 48 of Set 14 | ketchikan
# Processing Record 49 of Set 14 | nouakchott
# Processing Record 50 of Set 14 | tchibanga
# Processing Record 1 of Set 15 | blackfoot
# Processing Record 2 of Set 15 | roma
# Processing Record 3 of Set 15 | okhotsk
# Processing Record 4 of Set 15 | tingi
# Processing Record 5 of Set 15 | prince rupert
# Processing Record 6 of Set 15 | chibombo
# Processing Record 7 of Set 15 | boca do acre
# Processing Record 8 of Set 15 | bemidji
# Processing Record 9 of Set 15 | araouane
# Processing Record 10 of Set 15 | san cristobal
# Processing Record 11 of Set 15 | gat
# Processing Record 12 of Set 15 | atikokan
# Processing Record 13 of Set 15 | mercedes
# Processing Record 14 of Set 15 | zeya
# Processing Record 15 of Set 15 | turan
# Processing Record 16 of Set 15 | klaksvik
# Processing Record 17 of Set 15 | annamalainagar
# Processing Record 18 of Set 15 | suleja
# Processing Record 19 of Set 15 | damghan
# Processing Record 20 of Set 15 | ust-tsilma
# Processing Record 21 of Set 15 | shu
# Processing Record 22 of Set 15 | brigantine
# Processing Record 23 of Set 15 | new ulm
# Processing Record 24 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 15 | naranjal
# Processing Record 26 of Set 15 | nezhinka
# Processing Record 27 of Set 15 | camana
# Processing Record 28 of Set 15 | roebourne
# Processing Record 29 of Set 15 | zhanaozen
# Processing Record 30 of Set 15 | durban
# Processing Record 31 of Set 15 | tautira
# Processing Record 32 of Set 15 | malchevskaya
# Processing Record 33 of Set 15 | soyo
# Processing Record 34 of Set 15 | nazilli
# Processing Record 35 of Set 15 | umm lajj
# Processing Record 36 of Set 15 | tuni
# Processing Record 37 of Set 15 | kalmar
# Processing Record 38 of Set 15 | anchorage
# Processing Record 39 of Set 15 | caraquet
# Processing Record 40 of Set 15 | taltal
# Processing Record 41 of Set 15 | enkhuizen
# Processing Record 42 of Set 15 | lingdong
# Processing Record 43 of Set 15 | ponta delgada
# Processing Record 44 of Set 15 | kolokani
# Processing Record 45 of Set 15 | san carlos de bariloche
# Processing Record 46 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 47 of Set 15 | oda
# Processing Record 48 of Set 15 | kadnikov
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Faanui      PF -16.4833 -151.7500     81.28        73         100
# 1    Buraydah      SA  26.3260   43.9750     57.63        75           3
# 2      Narsaq      GL  60.9167  -46.0500     23.22        75           2
# 3   Ventspils      LV  57.3894   21.5606     42.73        81          90
# 4  Butaritari      KI   3.0707  172.7902     81.95        77          22
#
#    Wind Speed Current Description
# 0        7.18          light rain
# 1        8.84           clear sky
# 2        5.97           clear sky
# 3       17.27     overcast clouds
# 4       11.56          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
